# %% [markdown]
# # Process experimental data (fruit metabolite concentrations)

# %%
# %matplotlib inline
import numpy as np
from SweetloveGroup.dataProcessing import generateBoundsFromBiomass
#Day time points of interest
DAA = list(np.linspace(8,59,11))

mets = ("GLC","FRU","SUC","MAL","CIT","L_ALPHA_ALANINE","ASN","L_ASPARTATE","GABA","GLT","GLN","GLY","ILE","LYS","MET","PHE","PRO","SER","THR","TRP","TYR","VAL","Pi","FUM")
#mets = ("GLC",)
dfile="/home/sanu/JoseData_soluble_100818.csv"
Nsampl= 1000
Ssampl= 0.80

conc = dict()
flux_max = dict()
flux_min = dict()

for met in mets:
  print "Processing "+met+"..."
  [conc[met],flux_max[met],flux_min[met]]=generateBoundsFromBiomass(datafile = dfile,met=met,Nsampling=Nsampl,DPA=DAA,show_plots=True,degree=3,Ssampling=Ssampl,start=8,stop=59)


mets = ("STARCH",)
dfile="/home/sanu/JoseData_starch_protein_150818.csv"
Nsampl= 1000
Ssampl= 0.80

for met in mets:
  print "Processing "+met+"..."
  [conc[met],flux_max[met],flux_min[met]]=generateBoundsFromBiomass(datafile = dfile,met=met,Nsampling=Nsampl,DPA=DAA,show_plots=False,degree=3,Ssampling=Ssampl,start=8,stop=59)
# Out:
# Processing GLC...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-13bf221a667f> in <module>()
#      17 for met in mets:
#      18   print "Processing "+met+"..."
# ---> 19   [conc[met],flux_max[met],flux_min[met]]=generateBoundsFromBiomass(datafile = dfile,met=met,Nsampling=Nsampl,DPA=DAA,show_plots=True,degree=3,Ssampling=Ssampl,start=8,stop=59)
#      20
#      21
#
# ValueError: too many values to unpack

# %% [markdown]
# ### c) export processed data

# %%
mets = conc.keys()

fout = open("/home/sanu/JoseConc_301118.csv","w")
fout.write("DPA")
for met in mets:
  fout.write("\t"+met)

fout.write("\n")

for i in range(0,len(DAA)):
  fout.write(str(DAA[i]))
  for met in mets:
    fout.write("\t"+str(conc[met][i]))
  
  fout.write("\n")

fout.close()



fout = open("/home/sanu/JoseFluxMax_301118.csv","w")
fout.write("DPA")
for met in mets:
  fout.write("\t"+met)

fout.write("\n")

for i in range(0,len(DAA)):
  fout.write(str(DAA[i]))
  for met in mets:
    fout.write("\t"+str(flux_max[met][i]))
  
  fout.write("\n")

fout.close()



fout = open("/home/sanu/JoseFluxMin_301118.csv","w")
fout.write("DPA")
for met in mets:
  fout.write("\t"+met)

fout.write("\n")

for i in range(0,len(DAA)):
  fout.write(str(DAA[i]))
  for met in mets:
    fout.write("\t"+str(flux_min[met][i]))
  
  fout.write("\n")

fout.close()
